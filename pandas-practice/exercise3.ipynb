# %%
import pandas as pd

# %%
titanic = pd.read_csv("titanic.csv")

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
Ages = {
    "children": 0,
    "teen": 0,
    "adult": 0,
    "senior adult": 0
}

# %%
children = titanic[titanic["Age"]<13]

# %%
children
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 7              8         0       3            Palsson, Master. Gosta Leonard
# 10            11         1       3           Sandstrom, Miss. Marguerite Rut
# 16            17         0       3                      Rice, Master. Eugene
# 24            25         0       3             Palsson, Miss. Torborg Danira
# 43            44         1       2  Laroche, Miss. Simonne Marie Anne Andree
# ..           ...       ...     ...                                       ...
# 827          828         1       2                     Mallet, Master. Andre
# 831          832         1       2           Richards, Master. George Sibley
# 850          851         0       3   Andersson, Master. Sigvard Harald Elias
# 852          853         0       3                   Boulos, Miss. Nourelain
# 869          870         1       3           Johnson, Master. Harold Theodor
#
# ...

# %%
teen = titanic[(titanic["Age"]>12) & (titanic["Age"]<19)]

# %%
teen
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 9             10         1       2   Nasser, Mrs. Nicholas (Adele Achem)
# 14            15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
# 22            23         1       3           McGowan, Miss. Anna "Annie"
# 38            39         0       3    Vander Planke, Miss. Augusta Maria
# 39            40         1       3           Nicola-Yarred, Miss. Jamila
# ..           ...       ...     ...                                   ...
# 841          842         0       2              Mudd, Mr. Thomas Charles
# 844          845         0       3                   Culumovic, Mr. Jeso
# 853          854         1       1             Lines, Miss. Mary Conover
# 855          856         1       3            Aks, Mrs. Sam (Leah Rosen)
# 875          876         1       3      Najib, Miss. Adele Kiamie "Jane"
#
#         Sex   Age  SibSp  Parch       Ticket     Fare Cabin Embarked
# ...

# %%
adult = titanic[(titanic["Age"]>18) & (titanic["Age"]<60)]

# %%
adult
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
senior_adult = titanic[titanic["Age"]>59]

# %%
senior_adult
# Out:
#      PassengerId  Survived  Pclass  \
# 33            34         0       2
# 54            55         0       1
# 96            97         0       1
# 116          117         0       3
# 170          171         0       1
# 252          253         0       1
# 275          276         1       1
# 280          281         0       3
# 326          327         0       3
# 366          367         1       1
# 438          439         0       1
# 456          457         0       1
# 483          484         1       3
# 493          494         0       1
# 545          546         0       1
# 555          556         0       1
# 570          571         1       2
# 587          588         1       1
# 625          626         0       1
# 630          631         1       1
# 672          673         0       2
# 684          685         0       2
# 694          695         0       1
# 745          746         0       1
# 829          830         1       1
# ...

# %%
children.shape
# Out:
# (69, 12)

# %%
teen.shape
# Out:
# (70, 12)

# %%
adult.shape
# Out:
# (549, 12)

# %%
senior_adult.shape
# Out:
# (26, 12)

# %%
Ages["children"] = 69

# %%
Ages["teen"] = 70

# %%
Ages["adult"] = 549

# %%
Ages["senior adult"] = 26

# %%
Ages
# Out:
# {'children': 69, 'teen': 70, 'adult': 549, 'senior adult': 26}

# %%
children[children["Survived"] == 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 10            11         1       3
# 43            44         1       2
# 58            59         1       2
# 78            79         1       2
# 125          126         1       3
# 165          166         1       3
# 172          173         1       3
# 183          184         1       2
# 184          185         1       3
# 193          194         1       2
# 233          234         1       3
# 237          238         1       2
# 261          262         1       3
# 305          306         1       1
# 340          341         1       2
# 348          349         1       3
# 381          382         1       3
# 407          408         1       2
# 445          446         1       1
# 448          449         1       3
# 469          470         1       3
# 479          480         1       3
# 489          490         1       3
# 530          531         1       2
# 535          536         1       2
# ...

# %%
children[children["Survived"] == 1].shape
# Out:
# (40, 12)

# %%
Ages
# Out:
# {'children': 69, 'teen': 70, 'adult': 549, 'senior adult': 26}

# %%
Ages = {
    "children": {
        "all": 69,
        "servived": 40
    },
    "teen": {
        "all": 70,
        "servived": 30  
    },
    "adult": {
        "all": 549,
        "servived": 213
    },
    "senior_adult": {
        "all": 26,
        "servived": 7
    }
}

# %%
teen[teen["Survived"] == 1].shape
# Out:
# (30, 12)

# %%
adult[adult["Survived"] == 1].shape
# Out:
# (213, 12)

# %%
senior_adult[senior_adult["Survived"] == 1].shape
# Out:
# (7, 12)

# %%
69+70+549+26 #number of all passenger at first was 891
# Out:
# 714

# %%
titanic["Age"].dropna(axis=0, inplace=True, how="any")

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.iloc[:,5].isnull().sum() # We don't know that how old they were. So Operations don't work on them
# Out:
# 177

# %%
891 - 177
# Out:
# 714
